# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns; sns.set()

# %% [markdown]
# # Import instacart data

# %%
aisles = pd.read_csv("aisles.csv")
departments = pd.read_csv("departments.csv")
orders = pd.read_csv("orders.csv")
prior = pd.read_csv("order_products__prior.csv")
train = pd.read_csv("order_products__train.csv")
products = pd.read_csv("products.csv")

# %%
# appending train with prior to obtain whole sample size 
full = prior.append(train)

# %%
# sorting values by order id to keep some structure
full.sort_values(by = 'order_id', inplace = True, kind = 'mergesort')

# %%
# merging orders and full to include time and product information
full= full.merge(orders, on = 'order_id', how = 'left')

# %%
# merging to substitute id for actual name
full = full.merge(products, on = 'product_id', how = 'left')

# %%
# merging to substitute id for actual name
full = full.merge(aisles, on = 'aisle_id', how = 'left')

# %%
# merging to substitute id for actual name
full = full.merge(departments, on = 'department_id', how = 'left')

# %%
# removing id in place of actual name 
full.pop('product_id')
full.pop('aisle_id')
full.pop('department_id')
full.head()
# Out:
#    order_id  add_to_cart_order  reordered  user_id eval_set  order_number  \
# 0         1                  1          1   112108    train             4
# 1         1                  2          1   112108    train             4
# 2         1                  3          0   112108    train             4
# 3         1                  4          0   112108    train             4
# 4         1                  5          1   112108    train             4
#
#    order_dow  order_hour_of_day  days_since_prior_order  \
# 0          4                 10                     9.0
# 1          4                 10                     9.0
# 2          4                 10                     9.0
# 3          4                 10                     9.0
# 4          4                 10                     9.0
#
#                                     product_name                 aisle  \
# 0                               Bulgarian Yogurt                yogurt
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese  other creams cheeses
# 2                          Organic Celery Hearts      fresh vegetables
# 3                                 Cucumber Kirby      fresh vegetables
# 4           Lightly Smoked Sardines in Olive Oil   canned meat seafood
#
#      department
# 0    dairy eggs
# 1    dairy eggs
# 2       produce
# 3       produce
# 4  canned goods

# %%
# reordering sequence of columns for easy lookup
full = full[[ 'order_id',
             'order_number',
             'user_id',
             'department',
             'aisle',
             'product_name',
             'add_to_cart_order',
             'days_since_prior_order',
             'order_dow',
             'order_hour_of_day',
             'reordered',
             'eval_set']]
full.head()
# Out:
#    order_id  order_number  user_id    department                 aisle  \
# 0         1             4   112108    dairy eggs                yogurt
# 1         1             4   112108    dairy eggs  other creams cheeses
# 2         1             4   112108       produce      fresh vegetables
# 3         1             4   112108       produce      fresh vegetables
# 4         1             4   112108  canned goods   canned meat seafood
#
#                                     product_name  add_to_cart_order  \
# 0                               Bulgarian Yogurt                  1
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese                  2
# 2                          Organic Celery Hearts                  3
# 3                                 Cucumber Kirby                  4
# 4           Lightly Smoked Sardines in Olive Oil                  5
#
#    days_since_prior_order  order_dow  order_hour_of_day  reordered eval_set
# 0                     9.0          4                 10          1    train
# 1                     9.0          4                 10          1    train
# 2                     9.0          4                 10          0    train
# 3                     9.0          4                 10          0    train
# 4                     9.0          4                 10          1    train

# %% [markdown]
# # Feature Engineering

# %%
dff = full.sort_values(by ='user_id').head(10000)

# %%
dff.head(50)
# Out:
#           order_id  order_number  user_id  department                   aisle  \
# 4265667     431534             5        1   beverages             soft drinks
# 22289627   2254736             4        1      snacks  nuts seeds dried fruit
# 22289628   2254736             4        1  dairy eggs         packaged cheese
# 22289629   2254736             4        1   household             paper goods
# 22690192    prior
# 22690193    prior
# 5437567     prior
# 25103568    prior
# 25103567    prior
# 25103566    prior
# 25103565    prior
# 33289660    prior
# 25103564    prior
# 22289626    prior
# 11735958    train
# 22289625    prior
# 25212996    prior
# 4265672     prior
# 4265673     prior
# 4265674     prior
# 4265670     prior
# 25212989    prior
# 25212990    prior
# 25212991    prior
# 25212992    prior
# 25212993    prior
# 25212994    prior
# 4265669     prior
# 4265668     prior
# 22690188    prior
# 11735957    train
# 25212995    prior
# 25212997    prior
# 5437564     prior
# 5437563     prior
# 4681417     prior
# 4681418     prior
# 4681419     prior
# 33289657    prior
# 4681420     prior
# 23715286    prior
# 23715285    prior
# 23715284    prior
# 23715283    prior
# 23715282    prior
# 23715281    prior
# 30732193    prior

# %%
dff.fillna(0, axis = 0, inplace = True)

# %%
####restart point##########

# %%
# count of product per user 
grs = dff.groupby(['user_id']).product_name.value_counts()

# %%
# convert to data frame for merge
grs = grs.to_frame()

# %%
# renaming columns for reindex
grs.rename(columns = {'product_name' : 'product_counts'}, inplace = True)

# %%
grs.reset_index(inplace = True)

# %%
# number of orders to divide 
amount_orders = dff.groupby('user_id',as_index=False).order_number.max()

# %%
# merging number of orders with amount of products 
grs = grs.merge(amount_orders, on = 'user_id')

# %%
grs.rename(columns = {'order_number':'amount_orders'}, inplace = True)

# %%
grs.head()
# Out:
#    user_id           product_name  product_counts  amount_orders
# 0        1                   Soda              11             11
# 1        1    Original Beef Jerky              10             11
# 2        1             Pistachios              10             11
# 3        1  Organic String Cheese               9             11
# 4        1  Cinnamon Toast Crunch               4             11

# %%
grs = pd.merge(grs, dff[['user_id', 'order_id', 'order_number', 'product_name', 'department', 'aisle', 'add_to_cart_order', 'days_since_prior_order', 'order_dow', 'order_hour_of_day', 'reordered', 'eval_set' ]], on = ['user_id', 'product_name'], how = 'outer')

# %%
# ratio to infer how often the user purchases the same item 
grs['order_ratio'] = round(grs['product_counts'] / grs['amount_orders'], 3)

# %%
# count of the number of products purchased by user 
userct = grs.user_id.value_counts().to_frame().reset_index()
userct.columns = ['user_id', 'count']

# %%
# threshold to determine if user is an impulsive buyer 10% number of products repurchased
userrt = grs.where(grs['order_ratio'] > .10).user_id.value_counts().to_frame().reset_index()
userrt.columns = ['user_id', 'met_threshold']

# %%
# impulse ratio calculation  
impulse = userct.merge(userrt, on = 'user_id')
impulse['nonimpulse_ratio'] = impulse['met_threshold'] / impulse['count']

# %%
grs = grs.merge(impulse, on = 'user_id')

# %%
grs.drop(['count', 'met_threshold'], axis = 1, inplace = True)

# %%
grs.iloc[4000:4500]
# Out:
#       user_id                                       product_name  \
# 4000       31                                               Soda
# 4001       31                          Sparkling Cranberry Juice
# 4002       31                          Sparkling Cranberry Juice
# 4003       31                            Sparkling Pink Lemonade
# 4004       31                            Sparkling Pink Lemonade
# 4005       31   Spicy Mango With Jalapeño Smoked Chicken Sausage
# 4006       31   Spicy Mango With Jalapeño Smoked Chicken Sausage
# 4007       31                                  Swedish Meatballs
# 4008       31                                  Swedish Meatballs
# 4009       31             Synergy Organic & Raw Cosmic Cranberry
# 4010       31             Synergy Organic & Raw Cosmic Cranberry
# 4481                  condiments                  8                     1.0
# 4482                fresh fruits                 23                     1.0
# 4483                fresh fruits                 10                    30.0
# 4484                   dry pasta                 18                    30.0
# 4485                   dry pasta                 10                    22.0
# 4486                frozen pizza                  1                    30.0
# 4487                frozen pizza                 31                     1.0
# 4488            fresh vegetables                 17                    26.0
# 4489            fresh vegetables                  6                    22.0
# 4490        other creams cheeses                 20                    30.0
# 4491        other creams cheeses                 13                     1.0
# 4492            fresh vegetables                  9                    30.0
# 4493            fresh vegetables                 22                     1.0
# 4494             soy lactosefree                 26                    22.0
# 4495              frozen produce                 24                    22.0
# 4496                refrigerated                  5                    30.0
# 4497  doughs gelatins bake mixes                  8                    26.0
# 4498               oils vinegars                  2                     0.0
# 4499                     granola                  1                    30.0
#
#       order_dow  order_hour_of_day  reordered eval_set  order_ratio  \
# 4000          3                 11          1    prior        0.100
# 4001          2                  8          0    prior        0.100
# 4002          0                 17          1    prior        0.100
# 4003          2                  8          1    prior        0.100
# 4004          3                 13          0    prior        0.100
# 4005          0                 17          1    prior        0.100
# 4006          2                  9          0    prior        0.100
# 4007          5                 11          0    prior        0.100
# 4008          0                 17          1    prior        0.100
# 4009          3                 11          0    prior        0.100
# 4010          3                 11          1    prior        0.100
# 4011          5                 11          0    prior        0.100
# 4012          2                  8          1    prior        0.100
# 4013          0                 17          1    prior        0.100
# 4014          3                 11          0    prior        0.100
# 4015          0                 16          0    prior        0.100
# 4016          3                 11          1    prior        0.100
# 4017          2                  9          0    prior        0.100
# 4018          2                  8          1    prior        0.100
# 4019          4                 12          0    prior        0.100
# 4020          3                 11          1    prior        0.100
# 4021          0                 16          0    prior        0.100
# 4022          4                 12          1    prior        0.100
# 4023          0                 16          0    prior        0.100
# 4024          4                 12          1    prior        0.100
# 4025          3                 11          0    prior        0.100
# 4026          3                 11          1    prior        0.100
# 4027          1                  7          0    prior        0.050
# 4028          2                  8          0    prior        0.050
# 4029          2                 13          0    prior        0.050
# ...         ...                ...        ...      ...          ...
# 4470          3                 18          1    prior        0.222
# 4471          6                  9          0    prior        0.222
# 4472          6                 10          1    prior        0.222
# 4473          5                 16          0    prior        0.222
# 4474          6                 10          1    prior        0.222
# 4475          5                 16          0    prior        0.222
# 4476          3                 16          0    prior        0.222
# 4477          4                 17          1    prior        0.222
# 4478          5                 16          0    prior        0.222
# 4479          6                 10          1    prior        0.222
# 4480          5                 16          0    prior        0.222
# 4481          6                 10          1    prior        0.222
# 4482          6                 10          1    prior        0.222
# 4483          5                 16          0    prior        0.222
# 4484          6                  9          0    prior        0.222
# 4485          0                 20          1    prior        0.222
# 4486          5                 16          0    prior        0.222
# 4487          6                 10          1    prior        0.222
# 4488          3                 16          0    prior        0.222
# 4489          0                 20          1    prior        0.222
# 4490          5                 16          0    prior        0.222
# 4491          6                 10          1    prior        0.222
# 4492          5                 16          0    prior        0.222
# 4493          6                 10          1    prior        0.222
# 4494          0                 20          0    prior        0.111
# 4495          0                 20          0    prior        0.111
# 4496          6                  9          0    prior        0.111
# 4497          3                 16          0    prior        0.111
# 4498          5                 21          0    prior        0.111
# 4499          6                  9          0    prior        0.111
#
#       nonimpulse_ratio
# 4000          0.317726
# 4001          0.317726
# 4002          0.317726
# 4003          0.317726
# 4004          0.317726
# 4005          0.317726
# 4006          0.317726
# 4007          0.317726
# 4008          0.317726
# 4009          0.317726
# 4010          0.317726
# 4011          0.317726
# 4012          0.317726
# 4013          0.317726
# 4014          0.317726
# 4015          0.317726
# 4016          0.317726
# 4017          0.317726
# 4018          0.317726
# 4019          0.317726
# 4020          0.317726
# 4021          0.317726
# 4022          0.317726
# 4023          0.317726
# 4024          0.317726
# 4025          0.317726
# 4026          0.317726
# 4027          0.317726
# 4028          0.317726
# 4029          0.317726
# ...                ...
# 4470          1.000000
# 4471          1.000000
# 4472          1.000000
# 4473          1.000000
# 4474          1.000000
# 4475          1.000000
# 4476          1.000000
# 4477          1.000000
# 4478          1.000000
# 4479          1.000000
# 4480          1.000000
# 4481          1.000000
# 4482          1.000000
# 4483          1.000000
# 4484          1.000000
# 4485          1.000000
# 4486          1.000000
# 4487          1.000000
# 4488          1.000000
# 4489          1.000000
# 4490          1.000000
# 4491          1.000000
# 4492          1.000000
# 4493          1.000000
# 4494          1.000000
# 4495          1.000000
# 4496          1.000000
# 4497          1.000000
# 4498          1.000000
# 4499          1.000000
#
# [500 rows x 16 columns]

# %%
# sns.pairplot(data_raw)

# %% [markdown]
# # Preproccessing

# %%
grs.fillna(0, axis = 0, inplace = True)

# %%
grs.set_index(['user_id', 'order_id'], inplace = True)

# %%
ready = pd.get_dummies(grs, prefix = '', prefix_sep = '', columns = ['department', 'aisle', 'product_name'], dtype = 'int64')

# %%
# sns.pairplot(ready)

# %%
# training set
train = ready.loc[grs['eval_set'] == 'prior']

# %%
train.drop('eval_set', inplace = True, axis = 1)
# Out:
# C:\Users\marti\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 9516 entries, (1, 431534) to (74, 1386615)
# Columns: 3226 entries, product_counts to Zucchini Squash
# dtypes: float64(3), int64(3223)
# memory usage: 234.2 MB

# %%
# train.replace([np.inf, -np.inf], 0)

# %%
# Testing set
tests = ready.loc[grs['eval_set'] == 'train']

# %%
tests.drop('eval_set', inplace = True, axis = 1)

# %% [markdown]
# # Train and Test Set

# %%
X_test = tests.drop('reordered', axis = 1)
y_test = tests['reordered']

# %%
X = train.drop('reordered', axis = 1)
y = train['reordered']

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
lr = LogisticRegression(random_state = 13, class_weight = 'balanced')

# %%
lr.fit(X, y)
# Out:
# C:\Users\marti\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=13, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
tests.head()
# Out:
#                   product_counts  amount_orders  order_number  \
# user_id order_id
# 1       1187899               11             11            11
#         1187899               10             11            11
#         1187899                9             11            11
#         1187899                4             11            11
#         1187899                4             11            11
#
#                   add_to_cart_order  days_since_prior_order  order_dow  \
# user_id order_id
# 1       1187899                   1                    14.0          4
#         1187899                   6                    14.0          4
#         1187899                   2                    14.0          4
#         1187899                   7                    14.0          4
#         1187899                  11                    14.0          4
#
#                   order_hour_of_day  reordered  order_ratio  nonimpulse_ratio  \
# user_id order_id
# 1       1187899                   8          1        1.000               0.9
#         1187899                   8          1        0.909               0.9
#         1187899                   8          1        0.818               0.9
#         1187899                   8          1        0.364               0.9
#         1187899                   8          1        0.364               0.9
#
#                   ...  Zen Tea  Zero Calorie Cola  Zero Calorie Cola Soda  \
# user_id order_id  ...
# 1       1187899   ...        0                  0                       0
#         1187899   ...        0                  0                       0
#         1187899   ...        0                  0                       0
#         1187899   ...        0                  0                       0
#         1187899   ...        0                  1                       0
#
#                   Zero Calorie Tonic Water  \
# user_id order_id
# 1       1187899                          0
#         1187899                          0
#         1187899                          0
#         1187899                          0
#         1187899                          0
#
#                   Zero Calories Berry Nutrient Enhanced Water  \
# user_id order_id
# 1       1187899                                             0
#         1187899                                             0
#         1187899                                             0
#         1187899                                             0
#         1187899                                             0
#
#                   Zero Go-Go Mixed Berry Vitamin Water  Zero Soda  \
# user_id order_id
# 1       1187899                                      0          0
#         1187899                                      0          0
#         1187899                                      0          0
#         1187899                                      0          0
#         1187899                                      0          0
#
#                   Zero Vitamin Water  Zucchini Noodles  Zucchini Squash
# user_id order_id
# 1       1187899                    0                 0                0
#         1187899                    0                 0                0
#         1187899                    0                 0                0
#         1187899                    0                 0                0
#         1187899                    0                 0                0
#
# [5 rows x 3226 columns]

# %%
lr_pred = lr.predict(X_test)

# %%
confusion_matrix(y_test, lr_pred)
# Out:
# array([[183,   8],
#        [ 82, 211]], dtype=int64)

# %%
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.96      0.80       191
#            1       0.96      0.72      0.82       293
#
#     accuracy                           0.81       484
#    macro avg       0.83      0.84      0.81       484
# weighted avg       0.86      0.81      0.82       484

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(max_features="log2", max_depth=11, n_estimators=24,min_samples_split=1000, 
                               oob_score=True)

# %%
#fitting
rf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=11, max_features='log2', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=1000,
#                        min_weight_fraction_leaf=0.0, n_estimators=24,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#predictions
predrf = rf.predict(X_test)

# %%
confusion_matrix(y_test, predrf)
# Out:
# array([[103,  88],
#        [  4, 289]], dtype=int64)

# %%
print(classification_report(y_test, predrf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.54      0.69       191
#            1       0.77      0.99      0.86       293
#
#     accuracy                           0.81       484
#    macro avg       0.86      0.76      0.78       484
# weighted avg       0.84      0.81      0.80       484

# %% [markdown]
# # LGBM

# %%
import lightgbm as lgb

# %%
model= lgb.LGBMClassifier()

# %%
model.fit(X, y)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
pred=model.predict(X_test)

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[191,   0],
#        [  6, 287]], dtype=int64)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       191
#            1       1.00      0.98      0.99       293
#
#     accuracy                           0.99       484
#    macro avg       0.98      0.99      0.99       484
# weighted avg       0.99      0.99      0.99       484

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(X.values, y.values)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
# test_df.columns.duplicated().sum()
# xgboost does not like multi-index
# Out:
# 0

# %%
xgb_pred = model.predict(X_test)

# %%
confusion_matrix(y_test, xgb_pred)
# Out:
# array([[191,   0],
#        [  6, 287]], dtype=int64)

# %%
print(classification_report(y_test, xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       191
#            1       1.00      0.98      0.99       293
#
#     accuracy                           0.99       484
#    macro avg       0.98      0.99      0.99       484
# weighted avg       0.99      0.99      0.99       484

# %% [markdown]
# # Apriori

# %%
from apyori import apriori, load_transactions

# %%
items = prior[['order_id', 'product_id']]

# %%
transactions = []
for order in items['order_id']:
    transactions.append((order, item) for item in items['product_id'] )

# %%
rules = apriori(transactions)

# %%
results = list(rules)

# %%
results
